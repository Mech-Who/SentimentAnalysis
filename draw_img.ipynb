# %%
import matplotlib.pyplot as plt

# 准备数据点
x = range(1, 11)

# accuracy
rnn_gru = [0.6978, 0.786, 0.7929, 0.7974, 0.7968, 0.8039, 0.8038, 0.8101, 0.8102, 0.7906, 0.7956]
rnn_lstm = [0.6988, 0.7797, 0.7899, 0.7995, 0.8023, 0.804, 0.8076, 0.813, 0.8118, 0.7969, 0.8013]
rnn_simgle = [0.5906, 0.6864, 0.6896, 0.6979, 0.7023, 0.6811, 0.7169, 0.7293, 0.7206, 0.7296, 0.7299]
gru = [0.6978, 0.786, 0.7929, 0.7974, 0.7968, 0.8039, 0.8038, 0.8101, 0.8102, 0.7906, 0.7956]
lstm = [0.7104, 0.7868, 0.7968, 0.8054, 0.8049, 0.8075, 0.8104, 0.8135, 0.8175, 0.7941, 0.7989]
simple_rnn = [0.5987, 0.6131, 0.6933, 0.6965, 0.708, 0.7273, 0.61, 0.7198, 0.6897, 0.7166, 0.7207]
bi_lstm_attention = [0.685, 0.7891, 0.799, 0.8054, 0.8098, 0.8122, 0.8183, 0.8195, 0.8279, 0.7851, 0.7871]
bi_lstm_self_attention = [0.7024, 0.7838, 0.7938, 0.8001, 0.8089, 0.8135, 0.8179, 0.8239, 0.825, 0.7859, 0.7891]
bi_gru_attention = [0.677, 0.7899, 0.7993, 0.8045, 0.8102, 0.8122, 0.8182, 0.8262, 0.8282, 0.7813, 0.7841]

# 绘制 6 条折线图
plt.plot(x, rnn_gru[:len(x)], label='RNN(GRU Cell)', color='blue')
plt.plot(x, rnn_lstm[:len(x)], label='RNN(LSTM)', color='green')
plt.plot(x, rnn_simgle[:len(x)], label='RNN(SimpleRNN)', color='red')
plt.plot(x, gru[:len(x)], label='GRU', color='pink')
plt.plot(x, lstm[:len(x)], label='LSTM', color='purple')
plt.plot(x, simple_rnn[:len(x)], label='SimpleRNN', color='orange') 
plt.plot(x, bi_lstm_attention[:len(x)], label='Bi-LSTM(Attention)', color='gray')
plt.plot(x, bi_lstm_self_attention[:len(x)], label='Bi-LSTM(Self-attention)', color='black')
plt.plot(x, bi_gru_attention[:len(x)], label='Bi-GRU(Attention)', color='yellow')

# 添加图例
plt.legend()
plt.xlabel("epoch")
plt.ylabel("accuracy")

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

# 准备数据点
x = range(1, 11)

# f1-score
rnn_gru = [0.4888 ,0.5531, 0.558, 0.5607, 0.5609, 0.5654, 0.5659, 0.5694, 0.57, 0.5575]
rnn_lstm = [0.4899, 0.848, 0.5557, 0.5625, 0.5647, 0.5663, 0.5682, 0.5724, 0.5717, 0.5621]
rnn_simgle = [0.4252, 0.48, 0.4821, 0.4876, 0.4942, 0.4791 ,0.5033, 0.5122 ,0.5042, 0.5147]
gru = [0.4888, 0.5531, 0.558, 0.5607, 0.5609, 0.5654, 0.5659, 0.5694, 0.57, 0.5575]
lstm = [0.4984, 0.5534, 0.56, 0.566, 0.5666, 0.5685, 0.5705, 0.5729, 0.5751, 0.5601]
simple_rnn = [0.4262, 0.418, 0.4859, 0.4891, 0.4964, 0.5109, 0.4293, 0.5041, 0.4817, 0.5032]
bi_lstm_attention = [0.4858, 0.5554, 0.5677, 0.5784, 0.5893, 0.6036, 0.6133, 0.6255, 0.6505, 0.5893]
bi_lstm_self_attention = [0.4965, 0.5534, 0.5627, 0.5785, 0.5871, 0.604, 0.6139, 0.6311, 0.6484, 0.5881, 0.5891]
bi_gru_attention = [0.4872, 0.5631, 0.5753, 0.5914, 0.6054, 0.619, 0.6406, 0.6558, 0.6662, 0.6058, 0.6051]

# 绘制 6 条折线图
plt.plot(x, rnn_gru[:len(x)], label='RNN(GRU Cell)', color='blue')  # 线条为虚线，颜色为蓝色
plt.plot(x, rnn_lstm[:len(x)], label='RNN(LSTM)', color='green')  # 线条为点划线，颜色为绿色
plt.plot(x, rnn_simgle[:len(x)], label='RNN(SimpleRNN)', color='red')  # 线条为点线，颜色为红色
plt.plot(x, gru[:len(x)], label='GRU', color='pink')  # 线条为点线，颜色为红色
plt.plot(x, lstm[:len(x)], label='LSTM', color='purple')  # 线条为点线，颜色为红色
plt.plot(x, simple_rnn[:len(x)], label='SimpleRNN', color='orange')  # 线条为点线，颜色为红色
plt.plot(x, bi_lstm_attention[:len(x)], label='Bi-LSTM(Attention)', color='gray')
plt.plot(x, bi_lstm_self_attention[:len(x)], label='Bi-LSTM(Self-attention)', color='black')
plt.plot(x, bi_gru_attention[:len(x)], label='Bi-GRU(Attention)', color='yellow')

# 添加图例
plt.legend()
plt.xlabel("epoch")
plt.ylabel("f1-score")

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

# 准备数据点
x = range(1, 11)

# precision
rnn_gru = [0.7273, 0.7975, 0.8031, 0.808, 0.8058, 0.8124, 0.8119, 0.8173, 0.8174, 0.7961, 0.8013]
rnn_lstm = [0.7326, 0.7911, 0.8007, 0.81, 0.8124, 0.8144, 0.8177, 0.8226, 0.8201, 0.8038, 0.7083]
rnn_simgle = [0.6233, 0.6944, 0.6973, 0.7077, 0.7112, 0.6983, 0.7295, 0.74, 0.7262, 0.7354, 0.7356]
gru = [0.7273, 0.7975, 0.8031, 0.808, 0.8058, 0.8124, 0.8119, 0.8173, 0.8174, 0.7961, 0.8013]
lstm = [0.7522, 0.7984, 0.8076, 0.8167, 0.8157, 0.8173, 0.8199, 0.823, 0.8258, 0.8028, 0.8077]
simple_rnn = [0.6302, 0.6456, 0.7044, 0.7118, 0.7225, 0.7455, 0.6372, 0.7333, 0.7103, 0.72650, .731]
bi_lstm_attention = [0.7286, 0.8315, 0.842, 0.85, 0.8559, 0.8614, 0.8651, 0.872, 0.8774, 0.8313, 0.8339]
bi_lstm_self_attention = [0.7374, 0.8267, 0.8422, 0.8471, 0.8545, 0.8587, 0.8647, 0.8718, 0.8744, 0.8277, 0.8333]
bi_gru_attention = [0.7124, 0.8316, 0.8434, 0.8503, 0.8566, 0.8612, 0.8635, 0.8721, 0.8735 ,0.8262, 0.8301]

# 绘制 6 条折线图
plt.plot(x, rnn_gru[:len(x)], label='RNN(GRU Cell)', color='blue')  # 线条为虚线，颜色为蓝色
plt.plot(x, rnn_lstm[:len(x)], label='RNN(LSTM)', color='green')  # 线条为点划线，颜色为绿色
plt.plot(x, rnn_simgle[:len(x)], label='RNN(SimpleRNN)', color='red')  # 线条为点线，颜色为红色
plt.plot(x, gru[:len(x)], label='GRU', color='pink')  # 线条为点线，颜色为红色
plt.plot(x, lstm[:len(x)], label='LSTM', color='purple')  # 线条为点线，颜色为红色
plt.plot(x, simple_rnn[:len(x)], label='SimpleRNN', color='orange')  # 线条为点线，颜色为红色
plt.plot(x, bi_lstm_attention[:len(x)], label='Bi-LSTM(Attention)', color='gray')
plt.plot(x, bi_lstm_self_attention[:len(x)], label='Bi-LSTM(Self-attention)', color='black')
plt.plot(x, bi_gru_attention[:len(x)], label='Bi-GRU(Attention)', color='yellow')

# 添加图例
plt.legend()
plt.xlabel("epoch")
plt.ylabel("precision")

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

# 准备数据点
x = range(1, 11)

# recall
rnn_gru = [0.613, 0.7695, 0.7791, 0.7842, 0.7859, 0.7931, 0.7928, 0.8003, 0.7995, 0.7827, 0.7878]
rnn_lstm = [0.6099, 0.7635, 0.7743, 0.7866, 0.7907, 0.7905, 0.7953, 0.8026, 0.8024, 0.7882, 0.7921]
rnn_simgle = [0.4871, 0.67, 0.6727, 0.6769, 0.6847, 0.6425, 0.6947, 0.7114, 0.7115, 0.7204, 0.7213]
gru = [0.613, 0.7695, 0.7791, 0.7842, 0.7859, 0.7931, 0.7928, 0.8003, 0.7995, 0.7827, 0.7878]
lstm = [0.6091, 0.7694, 0.7823, 0.7906, 0.7915, 0.7965, 0.7991, 0.8033, 0.8079, 0.7841, 0.7891]
simple_rnn = [0.4983, 0.5054, 0.6704, 0.6642, 0.681, 0.6964, 0.5318, 0.697, 0.6428, 0.6983, 0.7029]
bi_lstm_attention = [0.6019, 0.7378, 0.7479, 0.7541, 0.7595, 0.7601, 0.7676, 0.7678, 0.7766, 0.7307, 0.7324]
bi_lstm_self_attention = [0.6335, 0.733, 0.7445, 0.7471, 0.7565, 0.7626, 0.7677, 0.7745, 0.7748, 0.7353, 0.7384]
bi_gru_attention = [0.6144, 0.7388, 0.7484, 0.7511, 0.7588, 0.7611, 0.7662, 0.776, 0.7797, 0.734, 0.7383]

# 绘制 6 条折线图
plt.plot(x, rnn_gru[:len(x)], label='RNN(GRU Cell)', color='blue')  # 线条为虚线，颜色为蓝色
plt.plot(x, rnn_lstm[:len(x)], label='RNN(LSTM)', color='green')  # 线条为点划线，颜色为绿色
plt.plot(x, rnn_simgle[:len(x)], label='RNN(SimpleRNN)', color='red')  # 线条为点线，颜色为红色
plt.plot(x, gru[:len(x)], label='GRU', color='pink')  # 线条为点线，颜色为红色
plt.plot(x, lstm[:len(x)], label='LSTM', color='purple')  # 线条为点线，颜色为红色
plt.plot(x, simple_rnn[:len(x)], label='SimpleRNN', color='orange')  # 线条为点线，颜色为红色
plt.plot(x, bi_lstm_attention[:len(x)], label='Bi-LSTM(Attention)', color='gray')
plt.plot(x, bi_lstm_self_attention[:len(x)], label='Bi-LSTM(Self-attention)', color='black')
plt.plot(x, bi_gru_attention[:len(x)], label='Bi-GRU(Attention)', color='yellow')

# 添加图例
plt.legend()
plt.xlabel("epoch")
plt.ylabel("recall")

# 显示图表
plt.show()
